# %%
import pandas as pd

# %%
 df = pd.read_csv('/Users/yasminbarree/Desktop/data science internship/globalterrorismdb.csv',encoding='ISO-8859-1')
# Out:
# /var/folders/lr/_tt5d_lj23dc_xvsbzjlhqs00000gn/T/ipykernel_15925/452391872.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/yasminbarree/Desktop/data science internship/globalterrorismdb.csv',encoding='ISO-8859-1')

# %%
print(df)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Dtype
# ---   ------              -----
#  0    eventid             int64
#  1    iyear               int64
#  2    imonth              int64
#  3    iday                int64
#  4    approxdate          object
#  5    extended            int64
#  6    resolution          object
#  7    country             int64
#  8    country_txt         object
#  9    region              int64
#  10   region_txt          object
#  11   provstate           object
#  12   city                object
#  13   latitude            float64
#  14   longitude           float64
#  15   specificity         float64
#  16   vicinity            int64
#  17   location            object
#  18   summary             object
#  19   crit1               int64
#  20   crit2               int64
#  21   crit3               int64
#  22   doubtterr           float64
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# # Information about the terrorist attacks:

# %%
#Terrorist attacks by region:
df['region_txt'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %%
print("Region with the most attacks:",df['region_txt'].value_counts().index[1])
# Out:
# Region with the most attacks: South Asia

# %%
#Terrorist attacks by country:

df['country_txt'].value_counts()
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: country_txt, Length: 205, dtype: int64

# %%
print("Counrty with the most attacks:",df['country_txt'].value_counts().index[1])
# Out:
# Counrty with the most attacks: Pakistan

# %%
#Who committed the terrorist attack ?
df['gname'].value_counts()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Ansar Sarallah                                          1
# Sword of Islam                                          1
# Support of Ocalan-The Hawks of Thrace                   1
# Arab Revolutionary Front                                1
# MANO-D                                                  1
# Name: gname, Length: 3537, dtype: int64

# %%
print("Group responsible for the most attacks:",df['gname'].value_counts().index[1])
# Out:
# Group responsible for the most attacks: Taliban

# %%
#Terrorist attacks based on city:
df['city'].value_counts()
# Out:
# Unknown      9775
# Baghdad      7589
# Karachi      2652
# Lima         2359
# Mosul        2265
#              ...
# Hotwag          1
# Ostend          1
# Balughata       1
# Jikoyi          1
# Kubentog        1
# Name: city, Length: 36674, dtype: int64

# %%
print("City with the most terrorist attack attacks:",df['city'].value_counts().index[1])
# Out:
# City with the most terrorist attack attacks: Baghdad

# %%
#Type of terrorist attacks:

df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
print("Most common terrorist attack type is :",df['attacktype1_txt'].value_counts().index[1])
# Out:
# Most common terrorist attack type is : Armed Assault

# %%
#Type of target of the terrorist attack:

df['targtype1_txt'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
print("Most common target is:",df['targtype1_txt'].value_counts().index[1])
# Out:
# Most common target is: Military

# %%
#Type of sub-target of the terrorist attack:

df['targsubtype1_txt'].value_counts()
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
#                                                            ...
# Multiple Telecommunication Targets                            31
# Fire Fighter/Truck                                            27
# Personnel                                                     19
# Oil Tanker                                                    19
# Internet Infrastructure                                       12
# Name: targsubtype1_txt, Length: 112, dtype: int64

# %%
#Terroist attacks by year: 
df['iyear'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: iyear, dtype: int64

# %%
print("Year with the most terrorist attacks:",df['iyear'].value_counts().idxmax())
# Out:
# Year with the most terrorist attacks: 2014

# %%
#Terroist attacks by nationality: 

df['natlty1_txt'].value_counts()
# Out:
# Iraq                              24113
# Pakistan                          13900
# India                             12098
# Afghanistan                       10931
# Colombia                           7922
#                                   ...
# People's Republic of the Congo        1
# Saba (Netherlands Antilles)           1
# Tuvalu                                1
# Western Sahara                        1
# Marshall Islands                      1
# Name: natlty1_txt, Length: 215, dtype: int64

# %%
df['casualties']=df['nkill']+df['nwound']
print("Country with highest casualties is:", df['natlty1_txt'].value_counts().index[0])
# Out:
# Country with highest casualties is: Iraq

# %%
df['casualties'] = df['nkill'] + df['nwound']

country_with_highest_casualties = df.groupby('natlty1_txt')['casualties'].sum().idxmax()
max_casualties = df.groupby('natlty1_txt')['casualties'].sum().max()

print(f"Country with the highest casualties ({max_casualties} casualties) is: {country_with_highest_casualties}")
# Out:
# Country with the highest casualties (198319.0 casualties) is: Iraq

# %% [markdown]
# # Graphs:

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
incidents_by_year = df['iyear'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.plot(incidents_by_year.index, incidents_by_year.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.title('Terrorist Incidents Over Time')
plt.grid(True)
plt.show()

# %%
incidents_by_region = df['region_txt'].value_counts()

plt.figure(figsize=(12, 6))
incidents_by_region.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Number of Incidents')
plt.title('High-Risk Regions for Terrorism')
plt.xticks(rotation=45)
plt.show()

# %%
attack_type_counts = df['attacktype1_txt'].value_counts()
attack_types = attack_type_counts.index
attack_counts = attack_type_counts.values
colors = plt.cm.Paired(np.arange(len(attack_types)))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 16))

wedges, texts, autotexts = ax1.pie(attack_counts, labels=attack_types, autopct='%1.1f%%', startangle=200, colors=colors)

legend_labels = [plt.Line2D([0], [0], marker='o', color='w', label=attack_type, markersize=10, markerfacecolor=color) for attack_type, color in zip(attack_types, colors)]
ax2.legend(handles=legend_labels, title='Attack Types', loc='upper left')

ax1.axis('equal')

ax1.set_title('Distribution of Attack Types')

ax2.axis('off')

fig.text(0.95, 0.02, "Figure 1", fontsize=15, color='gray', ha='right')

plt.tight_layout()

plt.show()

# %%
casualties_by_year = df.groupby('iyear')['casualties'].sum()

plt.figure(figsize=(12, 6))
plt.bar(casualties_by_year.index, casualties_by_year.values, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Casualties')
plt.title('Total Casualties in Terrorist Incidents by Year')
plt.xticks(rotation=45)  
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
merged_data = world.merge(df, left_on='name', right_on='country_txt', how='left')

df['casualties'] = df['nkill'] + df['nwound']

casualties_by_region = merged_data.groupby('region_txt')['casualties'].sum().reset_index()

region_with_highest_casualties = casualties_by_region.sort_values(by='casualties', ascending=False).iloc[0]['region_txt']

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax, linewidth=1, color='black')  # Draw country boundaries

region_to_color = merged_data[merged_data['region_txt'] == region_with_highest_casualties]
region_to_color.plot(column='casualties', cmap='YlOrRd_r', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=0, vmax=region_to_color['casualties'].max())

ax.set_title(f'Terrorist Attack Casualties by Region (Dark for {region_with_highest_casualties})')
ax.set_axis_off()

plt.show()

print("Region with the highest casualties is:", region_with_highest_casualties)
# Out:
# Region with the highest casualties is: Middle East & North Africa

# %%
import geopandas as gpd

merged_data = world.merge(df, left_on='name', right_on='country_txt', how='left')

df['casualties'] = df['nkill'] + df['nwound']

country_with_highest_casualties = df['natlty1_txt'].value_counts().index[0]

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax, linewidth=1, color='black')  # Draw country boundaries

region_to_color = merged_data[merged_data['country_txt'] == country_with_highest_casualties]
region_to_color.plot(column='casualties', cmap='YlOrRd_r', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=0, vmax=region_to_color['casualties'].max())

ax.set_title(f'Terrorist Attack Casualties by Region (Dark for {country_with_highest_casualties})')
ax.set_axis_off()

plt.show()

print("Country with the highest casualties is:", country_with_highest_casualties)
# Out:
# Country with the highest casualties is: Iraq
